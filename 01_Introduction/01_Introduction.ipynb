# %%
# some initialization stuff and general imports (see init.py for details)
# %run ../init.py
# %matplotlib inline
# Out:
# <style>
# .myalert {
#    margin:10pt;
#    border-left: 6px solid darkred;
#    background-color:#f5f5f5;
#    color:#0014ff;
#    text-align: center;
#    padding:10px;
#    font-size: 130%;
# }
#
# .mycomment {
#    font-size: 80%;
#    background-color:#f5f5f5;
#    padding: 5px;
# }
#
# .cite {
#    font-size: 80%;
#    color:#0000f5;
#    padding: 5px;
# }
#
# .mydef{
#     margin:10pt;
#     padding-left: 10pt;
#     border-left: 6px solid darkblue;
#     background-color:whitesmoke;
# }
#
# .reveal .slides section .fragment.step-fade-in-then-out {
#     opacity: 0;
#     display: none;
# }
#
# .reveal .slides section .fragment.step-fade-in-then-out.current-fragment {
#     opacity: 1;
#     display: inline;
# }
#
# </style>
# $$
# \gdef\rvar#1{\textrm{#1}}%
# \gdef\rvec#1{\mathbf{#1}}%
# \gdef\vec#1{\boldsymbol{#1}}%
# \gdef\tens#1{\boldsymbol{\mathsf{#1}}}%
# \gdef\tensel#1{\mathsf{#1}}%
# \gdef\st#1{\mathcal{#1}}%
# \gdef\diag#1{\textrm{diag}(\vec{#1})}%
# $$

# %% [markdown]
# ## Types of AI
#
# <hr>
# <center>
#     <img src="https://raw.githubusercontent.com/konstantin-schekotihin/dl_course/master/01_Introduction/images/ai_types.svg" width="70%"/>
# </center>

# %% [markdown]
# <center>
#     <img src="https://raw.githubusercontent.com/konstantin-schekotihin/dl_course/master/01_Introduction/images/ai_task_performance.png" width="70%"/>
# </center>

# %% [markdown]
# ## How do we learn?
#
# - Learning is an essential ability of any intelligent agent
# - There are two general approaches to learning _deductive_ and _inductive_
#     + **Deductive approach** corresponds to learning from a theory, e.g. from a textbook, when an agent gets the knowledge directly.
# <div class="mycomment">
# In AI this type of learning is used when we encode knowledge of an agent using some knowledge representation language and then use automatic reasoning to make decisions. Also usual programming is somewhat similar to the deductive type of learning, when a programmer encodes her knowledge about the domain in form of computational procedures. However, such agents cannot easily improve their performance over time.
# </div>
#     + **Inductive learning**, also known as _learning from experience_, is often used in practical settings, when an agent observes the environment and tries to find a model explaining how it works. The obtained knowledge is then used to improve performance of the agent in similar situations.

# %% [markdown]
# <div class="myalert"> <b>Machine learning</b> focuses on inductive learning and, therefore, agents using it can improve themselves with experience</div>

# %% [markdown]
# ## Symbolic and Subsymbolic AI
#
# - Knowledge can be stored in various forms

# %% [markdown]
# - **Symbolic** representation - logic and math
#    - Knowledge is represented as symbols and logical expressions
#         - *img-id01* has_physical_failure *FusedWire*
#         - *FusedWire* SubClassOf *PhysicalFailure*

# %% [markdown]
# - **Subsymbolic** representation - intuition, recognition
#     - Models mainly represent knowledge using various functions
#         - Model $w_0+w_1 T+w_2 E>0$ captures knowledge as coefficients $(w_0,w_1,w_2)$

# %% [markdown]
# <center>
#     <img src="https://raw.githubusercontent.com/konstantin-schekotihin/dl_course/master/01_Introduction/images/ai_symb_subs.svg" width="80%"/>
# </center>

# %% [markdown]
# ## Symbolic and Subsymbolic AI
#
# - **Symbolic AI**
#     - Deductive acquisition, learning at school
#     - Domain experts specify their knowledge using formal languages, e.g., ontologies
#     - *Precise* inference results using *search* and *optimization* methods

# %% [markdown]
# - **Subsymbolic AI**
#     - Inductive acquisition - learning from observations
#     - Domain knowledge is acquired from provided examples
#     - *Probabilistic* methods handle *uncertainty* in inputs and decision procedures

# %% [markdown]
# ## Weak AI: a Bird's-Eye View
#
# <hr>
# <center>
#     <img src="https://raw.githubusercontent.com/konstantin-schekotihin/dl_course/master/01_Introduction/images/weak_ai_overview.svg" width="90%"/>
# </center>

# %% [markdown]
# # Three types of learning
# <center>
#     <img src="https://raw.githubusercontent.com/konstantin-schekotihin/dl_course/master/01_Introduction/images/slide3.png" width="60%"/>
# </center>

# %% [markdown]
# <center>
#     <img src="https://raw.githubusercontent.com/konstantin-schekotihin/dl_course/master/01_Introduction/images/slide4.png" width="60%"/>
# </center>

# %% [markdown]
# <center>
#     <img src="https://raw.githubusercontent.com/konstantin-schekotihin/dl_course/master/01_Introduction/images/slide5.png" width="60%"/>
# </center>

# %% [markdown]
# ## ML universe
#
# <center>
#     <img src="https://raw.githubusercontent.com/konstantin-schekotihin/dl_course/master/01_Introduction/images/slide2.png" width="80%"/>
# </center>

# %% [markdown]
# # Learning task
#
# ML studies algorithms that
# - improve their **performance** $P$
# - at some **task** $T$
# - given **experience** $E$
#
# Well-defined **learning task** is a triple $\langle T,P,E \rangle$.

# %% [markdown]
# <div class="myalert">
#     Specify a learning task at the beginning of every ML project!
# </div>

# %% [markdown]
# ## Sample learning tasks
#
# - *Design an agent that plays chess*
#     - $T$: play Chess - for every position on a board find the best possible move, which maximizes the expected revenue of an agent,
#     - $P$: win the majority of games played in a round,
#     - $E$: games played as sequences of moves - human-human, human-agent, agent-agent

# %% [markdown]
# - *A continuous integration system must decide if tests must be run on the last push of changes or not*
#     - $T$: predict if code modifications represent changes in program functionality and therefore must be tested,
#     - $P$: minimize the number of bugs missed due to skipped tests,
#     - $E$: changesets from the repository with labels indicating if a test can be skipped or not

# %% [markdown]
# # ML problems
#
# - **Classification**: given a set of objects
#     - Binary or multi-class classification:
#         - partition objects into $k$ categories
#         - learn a probability distribution over mutually disjoint classes
#     - Multi-label classification:
#         - assign objects to at least one of the $k$ categories
#         - learn a marginal probability distribution

# %% [markdown]
# # ML problems, cont.
#
# - **Regression**: given some input predict a numerical value
# - **Sequence learning**: map a sequence of input objects to a sequence of target ones
#     - Tagging and parsing in NLP - text into part-of-speech
#     - Speech recognition: sequence of audio frames to words
#     - Text to speech: the inverse of the previous
#     - Machine translation: sequence of words in an input language to the sequence of words in the target one
# - **Time-series analysis**: given a series of past observations distributed in time predict  observations for the current or future time points
#     - For instance, anomaly detection aims at the identification of observations that are unusual or atypical wrt. past observations

# %% [markdown]
# # ML problems, cont.
#
# - **Representation learning**: automatically find representations of given object as a set of features, e.g., text, sound signals, or images into vectors, which can be used as input to other ML approach, e.g., a classifier
#     - Automates feature engineering
#     - Approaches exist for supervised, self-supervised, and unsupervised learning
# - **Generative modeling**: study patterns in data to generate data that highly likely could have been sampled from the original one
#   - Generative adversarial network (GAN) - two sub-models a generator, trained to generate data, and a discriminator, trained to determine whether the input data is real or generated. See this [list of GANs](https://thisxdoesnotexist.com/) for some funny examples.

# %% [markdown]
# ## Sample applications
#
# - *Computer vision* classification of images is the most well-known DL problem, see [ImageNet Challenge](https://arxiv.org/pdf/1409.0575.pdf)
#   - Image classification - predict type of an object on an input image
#   - Object localization - place bounding boxes locating objects on an image
#   - Object detection - localize objects and classify them
#   - Semantic segmentation - classify pixels of an image according to objects that they belong to
#
# - *Imputation of missing values*: values in input vectors are missing
#     - Learn to predict missing values and thus complete the observations
# - Natural language processing (NLP)
#   - Text classification - assign a label to the whole text
#   - Named entity recognition - classify n-grams (contiguous sequence of $n$ words)
# - Recommender systems
#   - Learning to rank - classes represent rankings of recommended items

# %% [markdown]
# # MLOps: a very brief overview

# %% [markdown]
# ## Step 1: Design a learning task
#
# - Identify the stakeholders and the business case for the future applications
# - Elaborate on possible ML applications for the selected use case - write a short and informal description
# - Sketch the learning task and discuss it with the stakeholders
#     - Often, a problem cannot be mapped clearly to a single learning task
#     - Select the most promising one
# - Describe the trade-offs/simplifications/abstractions you considered while defining your learning task
#     - Reevaluate the task as more information about the use case is available
#     - Modify the task and restart the process whenever, e.g.,
#         - the obtained solutions are not useful for the use case;
#         - the selected goals are not attainable, e.g., due to missing data, oversimplifications, unjustified expectations, etc.;
#         - the use case is changed by the stakeholders

# %% [markdown]
# ## Step 2: Collect training experience
#
# - Collect data sources that can provide training experience, databases, file shares, wikis, etc.
# - Analyze the data and store it in a uniform format suitable for your learning task
# - Inspect the stored data and evaluate its value for the selected learning task
#     - Does the data provide sufficient experience for a learner to solve the problem?
#     - Can experts given this data solve the same problem?
#     - Are statistical properties of the data satisfactory for the task?
#     - How well the data represents the real-world?
#         - Data states that all horses are black
# - And many more: sources, volumes, noise, trust, relevancy, etc.
# - Do not forget to assess costs: getting data can be expensive

# %% [markdown]
# ### Supervised learning
#
# + Often the data supposed for a supervised learning task is not labeled
#     - Labeling process is expensive and time consuming
#     - Evaluate different automatic scenarios, e.g., construct training examples aiming to reconstruct existing records
#         - E.g., mask a word in a sentence and train a model to predict it correctly
# + Type of feedback
#     - **direct**: every message in the inbox is labeled as *spam* or *not*, vs
#     - **indirect**: we know labels of messages and the overall user satisfaction score with the spam filter

# %% [markdown]
# ### Data preparation: training dataset
#
# - Using all available data for training is beneficial, but is almost impossible
#     - Testing performance of a model on the training data is counterproductive - overfitting results in better performance
#     - Deployment of a model to a productive environment is impossible - reputational risks
#     - Evaluate performance on a *test set* extracted from original data
# - Sampling of a test set can be done in various ways
#     - An expert can select representative messages and provide labels
#     - A learner selects the most problematic cases - active learning
#     - Random selection of examples - works well for representative data
#         - Different random sampling strategies, e.g., stratified sampling for small datasets
# - Select appropriate split ratio, e.g., 80% for training and 20% for testing

# %% [markdown]
# ### Data preparation: versioning
#
# + Define the *data versioning strategy*, e.g., in case of following events
#     - Different subsets of features can be beneficial for different models
#     - Data preprocessing, e.g., cleaning, rescaling, imputation
#     - Import of new examples
#     - Different sampling in dataset splits

# %% [markdown]
# ## Step 3: Model selection
#
# <div class="myalert">
#     A learner that makes <b>no prior assumptions</b> regarding the identity of the target concept has <b>no rational basis</b> for classifying any unseen instances (T. Mitchell, Machine Learning)
# </div>

# %% [markdown]
# + Defines the exact type of knowledge to be learned
#     - Target function $f : I \to O$ mapping an input to some output
#     - Example: given a student profile, output possible study length
#     - Example: given a set of documents, output a set of groups
#       comprising similar documents
# + Learning some functions might be difficult!
#     - Policy learning: $\mathit{BestMove}: \mathit{Position} \to \mathit{Move}$ (often hard)
#     - Action-value learning: $\mathit{Quality}: \mathit{Position} \to \mathbb{R}$ (relatively easy)

# %% [markdown]
# ### Model selection
#
# + A model provides a representation for the target knowledge
# + Model should be able to capture the theory you want to learn
#     - Possibilities: sets of logic rules, linear functions, (linear) combinations
#       of functions, sets (matrices) of representative data points, etc.
#     - Example: every board in Chess gets a quality value (a large matrix)
#     - Example: the revenue of a company depends linearly on a size of the advertisement budget

# %% [markdown]
# ## Step 4: Model training
#
# + Selection/design of a learning algorithm depends on a model
# + Must theoretically be able to fit a model to data: soundness, completeness
# + Computationally efficient - practical applicability (complexity)
# + Satisfy you requirements for precision and recall: optimization of the performance measure

# %% [markdown]
# - And, of course, do not forget about the computing power to cook it up!
#
# <center>
#     <img src="https://raw.githubusercontent.com/konstantin-schekotihin/dl_course/master/01_Introduction/images/slide7.png" width="20%"/>
# </center>

# %% [markdown]
# ## Step 5: Model evaluation (classification)
#
# - Comparison of predicted and actual labels for binary classification problem results in four values that form a **confusion matrix**
#   - $\mathit{TP}$ - number of true positives, "true" labels that were predicted as such
#   - $\mathit{FP}$ - number of false positives, type I error, rejecting a correct hypothesis
#   - $\mathit{TN}$ - number of true negatives
#   - $\mathit{FN}$ - number of false negatives, type II error, non-rejection of a false hypothesis
#
# $$
# \begin{array}{|c|c|}\hline
#     \mathit{TP} & \mathit{FP} \\
#     \hline
#     \mathit{FN} & \mathit{TN} \\ \hline
# \end{array}
# $$

# %% [markdown]
# - There are various performance measures which are selected wrt. particular learning task
# - Accuracy, good for balanced data
#
# \begin{equation*}
#  A = \frac{\mathit{TP} + \mathit{TN}} {\mathit{total}}
# \end{equation*}
#
#   - Precision, recall, and $F_1$-score, work for imbalanced data
#
# \begin{equation*}
#  P = \frac{\mathit{TP}}{\mathit{TP} + \mathit{FP}} ~~~~~
#  R = \frac{\mathit{TP}}{\mathit{TP} + \mathit{FN}} ~~~~~
#  F_1 = \frac{2PR}{P+R}
# \end{equation*}
#
# See, e.g., *Marina Sokolova, Guy Lapalme: [A systematic analysis of performance measures for classification tasks.](http://rali.iro.umontreal.ca/rali/sites/default/files/publis/SokolovaLapalme-JIPM09.pdf) Inf. Process. Manag. 45(4): 427-437 (2009)* for an overview
#
# Metrics usually shipped with ML frameworks, e.g., [Sklearn](https://scikit-learn.org/stable/modules/classes.html#module-sklearn.metrics) or [Torch](https://torchmetrics.readthedocs.io/en/latest/)

# %% [markdown]
# ### Visualizations
#
# - Confusion matrix: represents actual vs predicted labels
# - Receiver Operating Characteristic (ROC): plot of *recall vs precision* for different classification thresholds
#     - Area Under the Curve (AUC), a metric defined on the interval $[0,1]$, the closer is the measure to 1 the better

# %% [markdown]
# ### Model validation
#
# - Quite often learning algorithms can be parametrized
# - Selection of best values for **hyperparameters** is complicated
#   - How can we avoid **overfitting**, i.e., check how well a model generalizes to new data?
# - Validation of models trained with different setting is done using a **validation** set, which can be
#    - a specifically designed set of observations
#    - sampled from existing data - k-fold cross validation

# %% [markdown]
# ### k-fold Cross-Validation
# - Shuffle the dataset
# - Partition the dataset into k equal groups, and for each group
#     - Set the group as the test dataset
#     - Union remaining groups into a training dataset
#     - Fit a model and evaluate it using these sets
#     - Store the evaluation score
# - Estimate the performance of the model using stored evaluation scores

# %% [markdown]
# ## Step 6: ML Operations
#
# <center>
#     <img src="https://raw.githubusercontent.com/konstantin-schekotihin/dl_course/master/01_Introduction/attachment:image.png" width="60%"/>
# </center>
#
# - Deployment is mostly done in the cloud - use containers that comprise all required artifacts
#     - Model, its dependencies and environments (e.g., Python), configuration, metadata, cloud setup for load balancing and scale.
# - Introduce interfaces allowing your model to communicate with the environment
#     - Often models have a RESTful web service packaged with them
# - Implement a monitoring strategy ensuring quality management of your model over time
#     - Concept drift - characterization of classes by features changes over time
#     - Appearance of new classes not available during training

# %% [markdown]
# # Conclusions
#
# - Application of Machine Learning to solve real-world problems is easy as never before
# - Get clear understanding of your learning task before coding
# - Study your data: "Can you yourself get the results you want to get from the data at hand?"
# - Selection of a suitable machine learning approach is important
# - Analyze the performance measures
